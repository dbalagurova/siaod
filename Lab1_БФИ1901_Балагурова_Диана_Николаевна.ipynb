# %% [markdown]
# # Лабораторная работа №1
# ## Выполнила студентка группы БФИ1901 Балагурова Диана Николаевна
# ### Задание №1
# Описание условия задания

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from datetime import datetime
import random
import copy

def test_sort(matr, func, namesort):
    
    start_time = datetime.now()
    
    for i in range(len(matr)):
        func(matr[i])

    end_time = datetime.now()

    print(namesort)
    print(end_time - start_time)
    
    for i in range(len(matr) - 1):
        print(matr[i])


# Выбором
def selection_sort(alist):
    for i in range(0, len(alist) - 1):
        smallest = i
        for j in range(i + 1, len(alist)):
            if alist[j] < alist[smallest]:
                smallest = j
        alist[i], alist[smallest] = alist[smallest], alist[i]

# Вставкой
def insertion_sort(alist):
    for i in range(1, len(alist)):
        temp = alist[i]
        j = i - 1
        while (j >= 0 and temp < alist[j]):
            alist[j + 1] = alist[j]
            j = j - 1
        alist[j + 1] = temp
        
# Обменом
def bubble_sort(alist):
    for i in range(len(alist) - 1, 0, -1):
        no_swap = True
        for j in range(0, i):
            if alist[j + 1] < alist[j]:
                alist[j], alist[j + 1] = alist[j + 1], alist[j]
                no_swap = False
        if no_swap:
            return

# Шелла
def shell(data):
    inc = len(data) // 2
    while inc:
        for i, el in enumerate(data):
            while i >= inc and data[i - inc] > el:
                data[i] = data[i - inc]
                i -= inc
            data[i] = el
        inc = 1 if inc == 2 else int(inc * 5.0 / 11)
    return data

# Быстрая сортировка
def quicksort(alist, start = -1, end = -1):
    start = 0 if start == -1 else start
    end = len(alist) if end == -1 else end
    if end - start > 1:
        p = partition(alist, start, end)
        quicksort(alist, start, p)
        quicksort(alist, p + 1, end)
 
 
def partition(alist, start, end):
    pivot = alist[start]
    i = start + 1
    j = end - 1
 
    while True:
        while (i <= j and alist[i] <= pivot):
            i = i + 1
        while (i <= j and alist[j] >= pivot):
            j = j - 1
 
        if i <= j:
            alist[i], alist[j] = alist[j], alist[i]
        else:
            alist[start], alist[j] = alist[j], alist[start]
            return j

# Турнирная
def heapsort(alist):
    build_max_heap(alist)
    for i in range(len(alist) - 1, 0, -1):
        alist[0], alist[i] = alist[i], alist[0]
        max_heapify(alist, index=0, size=i)
 
def parent(i):
    return (i - 1)//2
 
def left(i):
    return 2*i + 1
 
def right(i):
    return 2*i + 2
 
def build_max_heap(alist):
    length = len(alist)
    start = parent(length - 1)
    while start >= 0:
        max_heapify(alist, index=start, size=length)
        start = start - 1
 
def max_heapify(alist, index, size):
    l = left(index)
    r = right(index)
    if (l < size and alist[l] > alist[index]):
        largest = l
    else:
        largest = index
    if (r < size and alist[r] > alist[largest]):
        largest = r
    if (largest != index):
        alist[largest], alist[index] = alist[index], alist[largest]
        max_heapify(alist, largest, size)
        
# Основная программа
m = int(input("Enter the m (50 - default value) : ") or "50")
n = int(input("Enter the n (50 - default value) : ") or "50")
min_lim = int(input("Enter the min_limit (-250 - default value) : ") or "-250")
max_lim = int(input("Enter the max_limit (1002 - default value) : ") or "1002")
matr = [[random.randint(min_lim, max_lim) for j in range(m)] for i in range(n+1)]
print(matr)

test_sort(copy.deepcopy(matr), list.sort, "Standart:")
test_sort(copy.deepcopy(matr), selection_sort, "Selection:")
test_sort(copy.deepcopy(matr), insertion_sort, "Insertion:")
test_sort(copy.deepcopy(matr), bubble_sort, "Change:")
test_sort(copy.deepcopy(matr), shell, "Shell:")
test_sort(copy.deepcopy(matr), quicksort, "Quick:")
test_sort(copy.deepcopy(matr), heapsort, "Pyramid:")
# Out:
# Enter the m (50 - default value) : 20
# Enter the n (50 - default value) : 15
# Enter the min_limit (-250 - default value) : -6
# Enter the max_limit (1002 - default value) : 9
# [[8, -2, 3, 5, -1, 8, -1, 8, 4, 2, 2, 3, 8, -2, 8, 1, 3, 7, 5, 9], [5, 3, 7, 1, 8, 4, 6, 8, 7, 8, -4, 5, -3, 0, 3, 2, 5, 8, 0, 3], [1, -6, 7, -3, 7, 9, -4, -3, -5, 0, 3, -2, -2, -2, 8, 2, -1, -5, 6, 0], [4, -5, 4, 0, -4, 9, 5, 0, 4, 4, 3, 3, 7, 7, 4, -5, -4, 6, -5, 0], [-5, 0, 0, -2, -3, 8, -5, -5, 0, 8, 7, 2, -3, -4, -2, 0, -5, -6, 0, 6], [-2, 7, -6, -2, 3, 5, -2, -1, -3, 4, -5, 4, 6, -1, 4, -4, 2, -2, 8, -2], [-2, 5, -5, 3, 3, 5, 4, 7, 7, 3, 3, 3, 2, -6, 7, -6, -2, 2, -5, 8], [-5, 3, -2, -1, 5, 0, 6, 1, -1, 2, -2, -2, 8, -2, -1, -2, 1, -6, -4, -6], [5, 0, 7, 6, 3, 4, 3, -4, 0, 1, 3, 7, 1, -4, 2, 9, 1, 3, -6, 7], [9, 4, 7, -6, 8, 0, 5, -6, 9, -5, -3, 1, 2, -3, -2, 9, 2, 0, 2, 1], [-5, -2, 4, 7, 8, -6, 8, 6, -2, 9, 4, 0, 0, -4, 6, 3, 5, 3, -5, 9], [-2, -6, 7, -2, 9, 2, 2, -3, 1, 7, 2, 2, 6, -5, 6, -5, -3, 2, -1, 7], [6, 1, 1, 4, 8, 2, 0, -3, -4, 3, 9, 9, -2, 1, -4, -1, 9, 0, -2, -5], [1, 4, -5, 6, 0, -6, 5, 5, -5, -4, 6, 2, -6, 4, -2, 1, 7, 5, -6, -3], [3, 4, 0, -4, -4, 7, 5, -5, -3, -4, 5, 0, 0, 7, 9, 4, -4, -2, 7, 0], [-1, 9, 6, -3, -2, 9, -3, 4, 7, -2, 6, -5, 1, 2, -2, 4, 9, 4, 6, 3]]
# Standart:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Selection:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Insertion:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Change:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Shell:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Quick:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
# Pyramid:
# 0:00:00
# [-2, -2, -1, -1, 1, 2, 2, 3, 3, 3, 4, 5, 5, 7, 8, 8, 8, 8, 8, 9]
# [-4, -3, 0, 0, 1, 2, 3, 3, 3, 4, 5, 5, 5, 6, 7, 7, 8, 8, 8, 8]
# [-6, -5, -5, -4, -3, -3, -2, -2, -2, -1, 0, 0, 1, 2, 3, 6, 7, 7, 8, 9]
# [-5, -5, -5, -4, -4, 0, 0, 0, 3, 3, 4, 4, 4, 4, 4, 5, 6, 7, 7, 9]
# [-6, -5, -5, -5, -5, -4, -3, -3, -2, -2, 0, 0, 0, 0, 0, 2, 6, 7, 8, 8]
# [-6, -5, -4, -3, -2, -2, -2, -2, -2, -1, -1, 2, 3, 4, 4, 4, 5, 6, 7, 8]
# [-6, -6, -5, -5, -2, -2, 2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 7, 7, 7, 8]
# [-6, -6, -5, -4, -2, -2, -2, -2, -2, -1, -1, -1, 0, 1, 1, 2, 3, 5, 6, 8]
# [-6, -4, -4, 0, 0, 1, 1, 1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 7, 7, 9]
# [-6, -6, -5, -3, -3, -2, 0, 0, 1, 1, 2, 2, 2, 4, 5, 7, 8, 9, 9, 9]
# [-6, -5, -5, -4, -2, -2, 0, 0, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9, 9]
# [-6, -5, -5, -3, -3, -2, -2, -1, 1, 2, 2, 2, 2, 2, 6, 6, 7, 7, 7, 9]
# [-5, -4, -4, -3, -2, -2, -1, 0, 0, 1, 1, 1, 2, 3, 4, 6, 8, 9, 9, 9]
# [-6, -6, -6, -5, -5, -4, -3, -2, 0, 1, 1, 2, 4, 4, 5, 5, 5, 6, 6, 7]
# [-5, -4, -4, -4, -4, -3, -2, 0, 0, 0, 0, 3, 4, 4, 5, 5, 7, 7, 7, 9]
